# %%
# import libraries 
import pandas as pd 
import numpy as np

# %%
# Data Set
List = [23,
38,
29,
28,
30,
28,
29,
27,
27,
28,
37,
]

# %%
List
# Out:
# [23, 38, 29, 28, 30, 28, 29, 27, 27, 28, 37]

# %%
n = len(List)
sumofList = sum(List)

# %%
#arithmetic mean
average = sumofList/n
average
# Out:
# 29.454545454545453

# %%
mean = np.mean(List)
mean
# Out:
# 29.454545454545453

# %%
mean = pd.mean(List)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 mean = pd.mean(List)
#
# AttributeError: module 'pandas' has no attribute 'mean'

# %%
#Median
